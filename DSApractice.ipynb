# %% [markdown]
# <a href="https://colab.research.google.com/github/lilh2o/DSApractice/blob/main/DSApractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("This file just changed test!")
# Out:
# This file just changed test!
